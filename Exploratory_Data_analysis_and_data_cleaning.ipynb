# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit-exe/Bike_Buyers/blob/main/Exploratory_Data_analysis_and_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/bike_buyers_clean.csv")

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.head()
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
df.describe()
# Out:
#                  ID         Income     Children         Cars          Age
# count   1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean   19965.992000   56140.000000     1.908000     1.452000    44.190000
# std     5347.333948   31081.609779     1.626094     1.124705    11.353537
# min    11000.000000   10000.000000     0.000000     0.000000    25.000000
# 25%    15290.750000   30000.000000     0.000000     1.000000    35.000000
# 50%    19744.000000   60000.000000     2.000000     1.000000    43.000000
# 75%    24470.750000   70000.000000     3.000000     2.000000    52.000000
# max    29447.000000  170000.000000     5.000000     4.000000    89.000000

# %%
df= df.drop_duplicates()

# %%
df.isnull()
# Out:
#         ID  Marital Status  Gender  Income  Children  Education  Occupation  \
# 0    False           False   False   False     False      False       False
# 1    False           False   False   False     False      False       False
# 2    False           False   False   False     False      False       False
# 3    False           False   False   False     False      False       False
# 4    False           False   False   False     False      False       False
# ..     ...             ...     ...     ...       ...        ...         ...
# 995  False           False   False   False     False      False       False
# 996  False           False   False   False     False      False       False
# 997  False           False   False   False     False      False       False
# 998  False           False   False   False     False      False       False
# 999  False           False   False   False     False      False       False
#
# ...

# %%
import seaborn as sns
sns.FacetGrid(df,hue='Occupation',size=10).map(sns.distplot,'Income').add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.boxplot(y='Income',data=df)

# %%
plt.bar(df["Occupation"],df["Commute Distance"])
# Out:
# <BarContainer object of 1000 artists>

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

df['Marital Status'] = label_encoder.fit_transform(df['Marital Status'].astype('str'))
df['Gender'] = label_encoder.fit_transform(df['Gender'].astype('str'))
df['Education'] = label_encoder.fit_transform(df['Education'].astype('str'))
df['Occupation'] = label_encoder.fit_transform(df['Occupation'].astype('str'))
df['Home Owner'] = label_encoder.fit_transform(df['Home Owner'].astype('str'))
df['Commute Distance'] = label_encoder.fit_transform(df['Commute Distance'].astype('str'))
df['Region'] = label_encoder.fit_transform(df['Region'].astype('str'))
df['Purchased Bike'] = label_encoder.fit_transform(df['Purchased Bike'].astype('str'))

df.set_index('ID')
# Out:
#        Marital Status  Gender  Income  Children  Education  Occupation  \
# ID
# 12496               0       0   40000         1          0           4
# 24107               0       1   30000         3          3           0
# 14177               0       1   80000         5          3           3
# 24381               1       1   70000         0          0           3
# 25597               1       1   30000         0          0           0
# ...               ...     ...     ...       ...        ...         ...
# 23731               0       1   60000         2          2           3
# 28672               1       1   70000         4          1           3
# 11809               0       1   60000         2          0           4
# 19664               1       1  100000         3          0           1
# 12121               1       1   60000         3          2           3
#
#        Home Owner  Cars  Commute Distance  Region  Age  Purchased Bike
# ID
# ...

# %%
df1 = pd.read_csv("/content/bike_buyers_clean.csv")
df1
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %%
reg=df1.Region.unique()

# %%
print(sorted(reg))
# Out:
# ['Europe', 'North America', 'Pacific']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    1000 non-null   int64
#  2   Gender            1000 non-null   int64
#  3   Income            1000 non-null   int64
#  4   Children          1000 non-null   int64
#  5   Education         1000 non-null   int64
#  6   Occupation        1000 non-null   int64
#  7   Home Owner        1000 non-null   int64
#  8   Cars              1000 non-null   int64
#  9   Commute Distance  1000 non-null   int64
#  10  Region            1000 non-null   int64
#  11  Age               1000 non-null   int64
#  12  Purchased Bike    1000 non-null   int64
# dtypes: int64(13)
# memory usage: 109.4 KB

# %%
print('Label unique Income:', df.Income.unique())
print('Label unique Children:', df.Children.unique())
print('Label unique Cars:', df.Cars.unique())
print('Label unique Age:', df.Age.unique())
# Out:
# Label unique Income: [ 40000  30000  80000  70000  10000 160000  20000  90000 170000  60000
#  100000 130000 120000 150000  50000 110000]
# Label unique Children: [1 3 5 0 2 4]
# Label unique Cars: [0 1 2 4 3]
# Label unique Age: [42 43 60 41 36 50 33 58 48 54 55 35 45 38 59 47 56 34 63 29 40 44 32 26
#  31 62 30 28 65 66 46 52 39 61 37 68 51 49 53 27 25 67 57 70 78 69 64 89
#  80 73 74 71 72]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()
scalled_income=sc.fit_transform(np.array(df['Income']).reshape(-1,1))

# %%
type(scalled_income)
# Out:
# numpy.ndarray

# %%
df['Income']=scalled_income

# %%
df=df.drop("ID",axis = 1)

# %%
import seaborn as sns
df.corr()
fig, ax = plt.subplots(figsize=(10,10)) 
ax = sns.heatmap(df.corr(), annot=True)

# %%
X= df[['Age']]
Y= df[['Income']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3,  random_state=0)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1000, 1) (700, 1) (300, 1)

# %%
print(X_train)
print(Y_train)
# Out:
#      Age
# 105   30
# 68    43
# 479   32
# 399   53
# 434   53
# ..   ...
# 835   40
# 192   62
# 629   35
# 559   58
# 684   42
#
# [700 rows x 1 columns]
#      Income
# 105  0.1250
# 68   0.0625
# 479  0.1875
# 399  0.1875
# 434  0.1250
# ..      ...
# 835  0.3125
# 192  0.4375
# 629  0.2500
# 559  0.3125
# 684  0.3125
#
# [700 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
#training the Logistic Regression model with training data
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# [0.12431432]
# [[0.00370367]]

# %%
y_pred = lr.predict(X_test)

# %%
print(type(y_pred))
# Out:
# <class 'numpy.ndarray'>

# %%
Y_test = np.array(Y_test)

# %%
print(type(Y_test))
# Out:
# <class 'numpy.ndarray'>

# %%
d = pd.DataFrame({'Actual': Y_test.flatten(), 'Predicted': y_pred.flatten()})
d
# Out:
#      Actual  Predicted
# 0    0.8750   0.287276
# 1    0.1250   0.305794
# 2    0.5000   0.324313
# 3    0.1875   0.394682
# 4    0.1875   0.235424
# ..      ...        ...
# 295  0.5625   0.253943
# 296  0.5625   0.265054
# 297  0.3125   0.302090
# 298  0.3750   0.302090
# 299  0.1250   0.324313
#
# [300 rows x 2 columns]

# %%
df1 = d.head(50)
df1.plot(kind='bar',figsize=(25,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, Y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.14229053939370861
# Mean Squared Error: 0.033701824306365855
# Root Mean Squared Error: 0.18358056625461708

# %%
import pickle

# %%
pickle.dump(lr, open('model.pkl','wb'))

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
#X=df[['Marital Status','Gender','Region']]
X=df.drop('Purchased Bike',axis=1)
Y=df['Purchased Bike']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3,  random_state=0)

# %%
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt
# %matplotlib inline
importances = mutual_info_classif(X,Y)
feat_importances = pd.Series(importances,df.columns[0:len(df.columns)-1])
feat_importances.plot(kind='barh',color='teal')
plt.show()

# %%
X=df[['Age','Cars','Education','Children','Commute Distance','Gender']]
# X=df.drop('Purchased Bike',axis=1)
Y=df['Purchased Bike']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3,  random_state=0)

# %%
model = RandomForestClassifier(n_estimators = 107,max_depth = 18,random_state =12)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=18, n_estimators=107, random_state=12)

# %%
score1 = model.score(X_train, Y_train)
score2 = model.score(X_test, Y_test)


print("Training set accuracy: ", '%.3f'%(score1))
print("Test set accuracy: ", '%.3f'%(score2))
# Out:
# Training set accuracy:  0.954
# Test set accuracy:  0.637

# %%
#n_estimators=107, max_depth=18, random_state=12

# %%
ma=0
mi=0
mj=0
for i in range(1,20):
  for j in range(1,20):
    for k in range(1,20):
      model = RandomForestClassifier(n_estimators = i, max_depth=j,random_state =k)
      model.fit(X_train, Y_train)
      score1 = model.score(X_train, Y_train)
      score2 = model.score(X_test, Y_test)
      if score2>ma:
        ma=score2
        mi=i
        mj=j
        mk=k
      print(score2,i,j,k)
# Out:
# 0.5966666666666667 1 1 1
# 0.5966666666666667 1 1 2
# 0.5433333333333333 1 1 3
# 0.5966666666666667 1 1 4
# 0.5466666666666666 1 1 5
# 0.5966666666666667 1 1 6
# 0.57 1 1 7
# 0.5966666666666667 1 1 8
# 0.5133333333333333 1 1 9
# 0.5966666666666667 1 1 10
# 0.5133333333333333 1 1 11
# 0.5133333333333333 1 1 12
# 0.5133333333333333 1 1 13
# 0.5966666666666667 1 1 14
# 0.5266666666666666 1 1 15
# 0.54 1 1 16
# 0.5066666666666667 1 1 17
# 0.5066666666666667 1 1 18
# 0.5366666666666666 1 1 19
# 0.6166666666666667 1 2 1
# 0.5933333333333334 1 2 2
# 0.6033333333333334 1 2 3
# 0.6066666666666667 1 2 4
# 0.59 1 2 5
# 0.6066666666666667 1 2 6
# 0.58 1 2 7
# 0.5933333333333334 1 2 8
# 0.56 1 2 9
# 0.58 1 2 10
# 0.5133333333333333 1 2 11
# 0.5933333333333334 1 2 12
# 0.56 1 2 13
# 0.6033333333333334 1 2 14
# 0.5933333333333334 1 2 15
# 0.58 1 2 16
# 0.53 1 2 17
# 0.5066666666666667 1 2 18
# 0.6066666666666667 1 2 19
# 0.58 1 3 1
# 0.5833333333333334 1 3 2
# 0.5933333333333334 1 3 3
# ...

# %%
print(ma,mi,mj,mk)

# %%
model = RandomForestClassifier(n_estimators = 19, max_depth=13,random_state =3)
model.fit(X_train, Y_train)
score1 = model.score(X_train, Y_train)
score2 = model.score(X_test, Y_test)
print(score1,score2)
# Out:
# 0.95 0.64

# %%
pickle.dump(model, open('bikebuyer.pkl','wb'))

# %%
0.7366666666666667
19 13 3
# Out:
#   File "<ipython-input-53-526c1f6890af>", line 2
#     19 13 3
#         ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(n_estimators = 100, max_depth = 152, random_state = 221)
  
# Fit to training set
gbr.fit(X_train, Y_train)
score1 = model.score(X_train, Y_train)
score2 = model.score(X_test, Y_test)

print(score2)
print(score2)
# Predict on test set
# pred_y = gbr.predict(test_X)
  
# # test set RMSE
# test_rmse = MSE(test_y, pred_y) ** (1 / 2)
  
# # Print rmse
# print('RMSE test set: {:.2f}'.format(test_rmse))
# Out:
# 0.64
# 0.64

# %%
for i in range(1,200):
      model = GradientBoostingRegressor(n_estimators=1, max_depth=5, random_state=2)
      model.fit(X_train, Y_train)
      score1 = model.score(X_train, Y_train)
      score2 = model.score(X_test, Y_test)
      print(score1,score2,i)
# Out:
# 0.05341832667493662 0.026459848781462014 1
# 0.05341832667493662 0.026459848781462014 2
# 0.05341832667493662 0.026459848781462014 3
# 0.05341832667493662 0.026459848781462014 4
# 0.05341832667493662 0.026459848781462014 5
# 0.05341832667493662 0.026459848781462014 6
# 0.05341832667493662 0.026459848781462014 7
# 0.05341832667493662 0.026459848781462014 8
# 0.05341832667493662 0.026459848781462014 9
# 0.05341832667493662 0.026459848781462014 10
# 0.05341832667493662 0.026459848781462014 11
# 0.05341832667493662 0.026459848781462014 12
# 0.05341832667493662 0.026459848781462014 13
# 0.05341832667493662 0.026459848781462014 14
# 0.05341832667493662 0.026459848781462014 15
# 0.05341832667493662 0.026459848781462014 16
# 0.05341832667493662 0.026459848781462014 17
# 0.05341832667493662 0.026459848781462014 18
# 0.05341832667493662 0.026459848781462014 19
# 0.05341832667493662 0.026459848781462014 20
# 0.05341832667493662 0.026459848781462014 21
# ...

# %%
X=df[['Cars','Education','Children','Commute Distance']]
#X=df.drop('Purchased Bike',axis=1)
Y=df['Purchased Bike']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25,  random_state=2)

# %%
from sklearn.neighbors import KNeighborsClassifier 

error1= []
error2= []
for k in range(1,15):
    knn= KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,Y_train)
    y_pred1= knn.predict(X_train)
    error1.append(np.mean(Y_train!= y_pred1))
    y_pred2= knn.predict(X_test)
    error2.append(np.mean(Y_test!= y_pred2))
# plt.figure(figsize(10,5))
plt.plot(range(1,15),error1,label="train")
plt.plot(range(1,15),error2,label="test")
plt.xlabel('k Value')
plt.ylabel('Error')
plt.legend()

# %%
knn= KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train,Y_train)
y_pred= knn.predict(X_test)
metrics.accuracy_score(Y_test,y_pred)
# Out:
# 0.692
